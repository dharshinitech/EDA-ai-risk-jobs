# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

df = pd.read_csv("ai_risk_jobs.csv")
df.head()
# Out:
#                  Job  Salary  AI_Risk_Score
# 0   Data Entry Clerk   25000             90
# 1     Content Writer   30000             70
# 2   Graphic Designer   35000             60
# 3  Software Engineer   80000             20
# 4         Accountant   40000             65

# %%
df.shape
# Out:
# (10, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Job            10 non-null     object
#  1   Salary         10 non-null     int64
#  2   AI_Risk_Score  10 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 372.0+ bytes

# %%
df.describe()
# Out:
#              Salary  AI_Risk_Score
# count     10.000000      10.000000
# mean   37000.000000      52.500000
# std    17217.562094      26.900021
# min    20000.000000      10.000000
# 25%    28500.000000      32.500000
# 50%    31000.000000      57.500000
# 75%    38750.000000      68.750000
# max    80000.000000      90.000000

# %%
import matplotlib.pyplot as plt

df['AI_Risk_Score'].hist()
plt.title("AI Risk Score Distribution")
plt.xlabel("AI Risk Score")
plt.ylabel("Count")
plt.show()

# %%
df.plot.scatter(x="Salary", y="AI_Risk_Score")
plt.title("Salary vs AI Risk")
plt.show()

# %%
df.sort_values("AI_Risk_Score", ascending=False)
# Out:
#                  Job  Salary  AI_Risk_Score
# 0   Data Entry Clerk   25000             90
# 7  Call Center Agent   28000             85
# 1     Content Writer   30000             70
# 4         Accountant   40000             65
# 2   Graphic Designer   35000             60
# 8       HR Assistant   32000             55
# 5            Teacher   30000             40
# 9  Marketing Analyst   50000             30
# 3  Software Engineer   80000             20
# 6     Security Guard   20000             10

# %%
df.isnull().sum()
# Out:
# Job              0
# Salary           0
# AI_Risk_Score    0
# dtype: int64

# %% [markdown]
# EDA Summary:
# - The dataset contains job roles, salary, and AI risk score
# - Jobs like Data Entry Clerk show higher AI risk
# - Higher salary jobs tend to have lower AI risk
# - No major missing values were found
# - Dataset is clean and suitable for analysis

# %% [markdown]
# Final EDA Summary:
# - The dataset consists of 10 job roles with salary and AI risk score details
# - The data contains both categorical and numerical variables
# - No missing values were detected, indicating good data quality
# - Jobs with higher salaries generally show lower AI risk
# - The dataset is suitable for further visualization and analysis
